# %% [markdown]
# # Keep The Best Models During Training with Checkpointing
#
# reference: Deep Learning with Python chapter 14
#
# You will know:
# - The importance of checkpointing neural network models when training
# - How to checkpoint each improvement to a model during training
# - How to checkpoint the very best model observed during training

# %%
### Checkpoint Neural Network Model Improvements
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
#load pima indians dataset
dataset = numpy.loadtxt("../datasets/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath = "weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_acc improved from -inf to 0.67323, saving model to weights-improvement-01-0.67.hdf5
#
# Epoch 00002: val_acc did not improve from 0.67323
#
# Epoch 00003: val_acc did not improve from 0.67323
#
# Epoch 00004: val_acc did not improve from 0.67323
#
# Epoch 00005: val_acc did not improve from 0.67323
#
# Epoch 00006: val_acc improved from 0.67323 to 0.69685, saving model to weights-improvement-06-0.70.hdf5
#
# Epoch 00007: val_acc did not improve from 0.69685
#
# Epoch 00008: val_acc improved from 0.69685 to 0.71654, saving model to weights-improvement-08-0.72.hdf5
#
# Epoch 00009: val_acc did not improve from 0.71654
#
# Epoch 00010: val_acc did not improve from 0.71654
#
# Epoch 00011: val_acc did not improve from 0.71654
#
# Epoch 00012: val_acc improved from 0.71654 to 0.72441, saving model to weights-improvement-12-0.72.hdf5
#
# Epoch 00013: val_acc did not improve from 0.72441
#
# Epoch 00014: val_acc did not improve from 0.72441
#
# Epoch 00015: val_acc did not improve from 0.72441
#
# Epoch 00016: val_acc did not improve from 0.72441
#
# Epoch 00017: val_acc did not improve from 0.72441
#
# Epoch 00018: val_acc did not improve from 0.72441
#
# Epoch 00019: val_acc did not improve from 0.72441
#
# Epoch 00020: val_acc did not improve from 0.72441
#
# Epoch 00021: val_acc did not improve from 0.72441
#
# Epoch 00022: val_acc did not improve from 0.72441
#
# Epoch 00023: val_acc did not improve from 0.72441
#
# Epoch 00024: val_acc did not improve from 0.72441
#
# Epoch 00025: val_acc did not improve from 0.72441
#
# Epoch 00026: val_acc did not improve from 0.72441
#
# Epoch 00027: val_acc did not improve from 0.72441
#
# Epoch 00028: val_acc did not improve from 0.72441
#
# Epoch 00029: val_acc did not improve from 0.72441
#
# Epoch 00030: val_acc did not improve from 0.72441
#
# Epoch 00031: val_acc did not improve from 0.72441
#
# Epoch 00032: val_acc did not improve from 0.72441
#
# Epoch 00033: val_acc did not improve from 0.72441
#
# Epoch 00034: val_acc did not improve from 0.72441
#
# Epoch 00035: val_acc did not improve from 0.72441
#
# Epoch 00036: val_acc did not improve from 0.72441
#
# Epoch 00037: val_acc improved from 0.72441 to 0.72441, saving model to weights-improvement-37-0.72.hdf5
#
# Epoch 00038: val_acc did not improve from 0.72441
#
# Epoch 00039: val_acc improved from 0.72441 to 0.73228, saving model to weights-improvement-39-0.73.hdf5
#
# Epoch 00040: val_acc improved from 0.73228 to 0.73622, saving model to weights-improvement-40-0.74.hdf5
#
# Epoch 00041: val_acc did not improve from 0.73622
#
# Epoch 00042: val_acc did not improve from 0.73622
#
# Epoch 00043: val_acc improved from 0.73622 to 0.74016, saving model to weights-improvement-43-0.74.hdf5
#
# Epoch 00044: val_acc did not improve from 0.74016
#
# Epoch 00045: val_acc did not improve from 0.74016
#
# Epoch 00046: val_acc did not improve from 0.74016
#
# Epoch 00047: val_acc improved from 0.74016 to 0.74409, saving model to weights-improvement-47-0.74.hdf5
#
# Epoch 00048: val_acc did not improve from 0.74409
#
# Epoch 00049: val_acc did not improve from 0.74409
#
# Epoch 00050: val_acc did not improve from 0.74409
#
# Epoch 00051: val_acc did not improve from 0.74409
#
# Epoch 00052: val_acc did not improve from 0.74409
#
# Epoch 00053: val_acc did not improve from 0.74409
#
# Epoch 00054: val_acc improved from 0.74409 to 0.75197, saving model to weights-improvement-54-0.75.hdf5
#
# Epoch 00055: val_acc did not improve from 0.75197
#
# Epoch 00056: val_acc did not improve from 0.75197
#
# Epoch 00057: val_acc did not improve from 0.75197
#
# Epoch 00058: val_acc did not improve from 0.75197
#
# Epoch 00059: val_acc did not improve from 0.75197
#
# Epoch 00060: val_acc did not improve from 0.75197
#
# Epoch 00061: val_acc did not improve from 0.75197
#
# Epoch 00062: val_acc improved from 0.75197 to 0.75591, saving model to weights-improvement-62-0.76.hdf5
#
# Epoch 00063: val_acc did not improve from 0.75591
#
# Epoch 00064: val_acc improved from 0.75591 to 0.75984, saving model to weights-improvement-64-0.76.hdf5
#
# Epoch 00065: val_acc did not improve from 0.75984
#
# Epoch 00066: val_acc did not improve from 0.75984
#
# Epoch 00067: val_acc did not improve from 0.75984
#
# Epoch 00068: val_acc did not improve from 0.75984
#
# Epoch 00069: val_acc improved from 0.75984 to 0.76378, saving model to weights-improvement-69-0.76.hdf5
#
# Epoch 00070: val_acc did not improve from 0.76378
#
# Epoch 00071: val_acc did not improve from 0.76378
#
# Epoch 00072: val_acc improved from 0.76378 to 0.77559, saving model to weights-improvement-72-0.78.hdf5
#
# Epoch 00073: val_acc did not improve from 0.77559
#
# Epoch 00074: val_acc did not improve from 0.77559
#
# Epoch 00075: val_acc did not improve from 0.77559
#
# Epoch 00076: val_acc did not improve from 0.77559
#
# Epoch 00077: val_acc did not improve from 0.77559
#
# Epoch 00078: val_acc improved from 0.77559 to 0.77559, saving model to weights-improvement-78-0.78.hdf5
#
# Epoch 00079: val_acc did not improve from 0.77559
#
# Epoch 00080: val_acc did not improve from 0.77559
#
# Epoch 00081: val_acc did not improve from 0.77559
#
# Epoch 00082: val_acc did not improve from 0.77559
#
# Epoch 00083: val_acc did not improve from 0.77559
#
# Epoch 00084: val_acc did not improve from 0.77559
#
# Epoch 00085: val_acc did not improve from 0.77559
#
# Epoch 00086: val_acc did not improve from 0.77559
#
# Epoch 00087: val_acc did not improve from 0.77559
#
# Epoch 00088: val_acc did not improve from 0.77559
#
# Epoch 00089: val_acc did not improve from 0.77559
#
# Epoch 00090: val_acc did not improve from 0.77559
#
# Epoch 00091: val_acc did not improve from 0.77559
#
# Epoch 00092: val_acc did not improve from 0.77559
#
# Epoch 00093: val_acc did not improve from 0.77559
#
# Epoch 00094: val_acc did not improve from 0.77559
#
# Epoch 00095: val_acc did not improve from 0.77559
#
# Epoch 00096: val_acc did not improve from 0.77559
#
# Epoch 00097: val_acc did not improve from 0.77559
#
# Epoch 00098: val_acc did not improve from 0.77559
#
# Epoch 00099: val_acc improved from 0.77559 to 0.78740, saving model to weights-improvement-99-0.79.hdf5
#
# Epoch 00100: val_acc did not improve from 0.78740
#
# Epoch 00101: val_acc did not improve from 0.78740
#
# Epoch 00102: val_acc did not improve from 0.78740
#
# Epoch 00103: val_acc did not improve from 0.78740
#
# Epoch 00104: val_acc did not improve from 0.78740
#
# Epoch 00105: val_acc did not improve from 0.78740
#
# Epoch 00106: val_acc did not improve from 0.78740
#
# Epoch 00107: val_acc did not improve from 0.78740
#
# Epoch 00108: val_acc did not improve from 0.78740
#
# Epoch 00109: val_acc did not improve from 0.78740
#
# Epoch 00110: val_acc did not improve from 0.78740
#
# Epoch 00111: val_acc did not improve from 0.78740
#
# Epoch 00112: val_acc did not improve from 0.78740
#
# Epoch 00113: val_acc did not improve from 0.78740
#
# Epoch 00114: val_acc did not improve from 0.78740
#
# Epoch 00115: val_acc did not improve from 0.78740
#
# Epoch 00116: val_acc did not improve from 0.78740
#
# Epoch 00117: val_acc did not improve from 0.78740
#
# Epoch 00118: val_acc did not improve from 0.78740
#
# Epoch 00119: val_acc did not improve from 0.78740
#
# Epoch 00120: val_acc did not improve from 0.78740
#
# Epoch 00121: val_acc did not improve from 0.78740
#
# Epoch 00122: val_acc did not improve from 0.78740
#
# Epoch 00123: val_acc did not improve from 0.78740
#
# Epoch 00124: val_acc did not improve from 0.78740
#
# Epoch 00125: val_acc did not improve from 0.78740
#
# Epoch 00126: val_acc did not improve from 0.78740
#
# Epoch 00127: val_acc did not improve from 0.78740
#
# Epoch 00128: val_acc did not improve from 0.78740
#
# Epoch 00129: val_acc did not improve from 0.78740
#
# Epoch 00130: val_acc improved from 0.78740 to 0.79921, saving model to weights-improvement-130-0.80.hdf5
#
# Epoch 00131: val_acc did not improve from 0.79921
#
# Epoch 00132: val_acc did not improve from 0.79921
#
# Epoch 00133: val_acc did not improve from 0.79921
#
# Epoch 00134: val_acc did not improve from 0.79921
#
# Epoch 00135: val_acc did not improve from 0.79921
#
# Epoch 00136: val_acc did not improve from 0.79921
#
# Epoch 00137: val_acc did not improve from 0.79921
#
# Epoch 00138: val_acc did not improve from 0.79921
#
# Epoch 00139: val_acc did not improve from 0.79921
#
# Epoch 00140: val_acc did not improve from 0.79921
#
# Epoch 00141: val_acc did not improve from 0.79921
#
# Epoch 00142: val_acc did not improve from 0.79921
#
# Epoch 00143: val_acc did not improve from 0.79921
#
# Epoch 00144: val_acc did not improve from 0.79921
# Epoch 00145: val_acc did not improve from 0.79921
#
# Epoch 00146: val_acc did not improve from 0.79921
#
# Epoch 00147: val_acc did not improve from 0.79921
#
# Epoch 00148: val_acc did not improve from 0.79921
#
# Epoch 00149: val_acc did not improve from 0.79921
#
# Epoch 00150: val_acc did not improve from 0.79921

# %%
### Checkpoint Best Neural Network Model Only
# save the model weights to the same file, if and only if the validation accuracy improves
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
#load pima indians dataset
dataset = numpy.loadtxt("../datasets/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath = "weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 00001: val_acc improved from -inf to 0.67323, saving model to weights.best.hdf5
#
# Epoch 00002: val_acc did not improve from 0.67323
#
# Epoch 00003: val_acc did not improve from 0.67323
#
# Epoch 00004: val_acc improved from 0.67323 to 0.68898, saving model to weights.best.hdf5
#
# Epoch 00005: val_acc improved from 0.68898 to 0.70079, saving model to weights.best.hdf5
#
# Epoch 00006: val_acc did not improve from 0.70079
#
# Epoch 00007: val_acc did not improve from 0.70079
#
# Epoch 00008: val_acc did not improve from 0.70079
#
# Epoch 00009: val_acc improved from 0.70079 to 0.70079, saving model to weights.best.hdf5
#
# Epoch 00010: val_acc did not improve from 0.70079
#
# Epoch 00011: val_acc did not improve from 0.70079
#
# Epoch 00012: val_acc improved from 0.70079 to 0.71260, saving model to weights.best.hdf5
#
# Epoch 00013: val_acc did not improve from 0.71260
#
# Epoch 00014: val_acc did not improve from 0.71260
#
# Epoch 00015: val_acc did not improve from 0.71260
#
# Epoch 00016: val_acc did not improve from 0.71260
#
# Epoch 00017: val_acc improved from 0.71260 to 0.71654, saving model to weights.best.hdf5
#
# Epoch 00018: val_acc did not improve from 0.71654
#
# Epoch 00019: val_acc did not improve from 0.71654
#
# Epoch 00020: val_acc did not improve from 0.71654
#
# Epoch 00021: val_acc did not improve from 0.71654
#
# Epoch 00022: val_acc improved from 0.71654 to 0.72047, saving model to weights.best.hdf5
#
# Epoch 00023: val_acc did not improve from 0.72047
#
# Epoch 00024: val_acc did not improve from 0.72047
#
# Epoch 00025: val_acc did not improve from 0.72047
#
# Epoch 00026: val_acc did not improve from 0.72047
#
# Epoch 00027: val_acc did not improve from 0.72047
#
# Epoch 00028: val_acc did not improve from 0.72047
#
# Epoch 00029: val_acc improved from 0.72047 to 0.72835, saving model to weights.best.hdf5
#
# Epoch 00030: val_acc improved from 0.72835 to 0.72835, saving model to weights.best.hdf5
#
# Epoch 00031: val_acc did not improve from 0.72835
#
# Epoch 00032: val_acc did not improve from 0.72835
#
# Epoch 00033: val_acc did not improve from 0.72835
#
# Epoch 00034: val_acc did not improve from 0.72835
#
# Epoch 00035: val_acc did not improve from 0.72835
#
# Epoch 00036: val_acc did not improve from 0.72835
#
# Epoch 00037: val_acc did not improve from 0.72835
#
# Epoch 00038: val_acc did not improve from 0.72835
#
# Epoch 00039: val_acc improved from 0.72835 to 0.74016, saving model to weights.best.hdf5
#
# Epoch 00040: val_acc did not improve from 0.74016
#
# Epoch 00041: val_acc did not improve from 0.74016
#
# Epoch 00042: val_acc did not improve from 0.74016
#
# Epoch 00043: val_acc improved from 0.74016 to 0.74409, saving model to weights.best.hdf5
#
# Epoch 00044: val_acc did not improve from 0.74409
#
# Epoch 00045: val_acc did not improve from 0.74409
#
# Epoch 00046: val_acc did not improve from 0.74409
#
# Epoch 00047: val_acc did not improve from 0.74409
#
# Epoch 00048: val_acc did not improve from 0.74409
#
# Epoch 00049: val_acc did not improve from 0.74409
#
# Epoch 00050: val_acc did not improve from 0.74409
#
# Epoch 00051: val_acc did not improve from 0.74409
#
# Epoch 00052: val_acc did not improve from 0.74409
#
# Epoch 00053: val_acc did not improve from 0.74409
#
# Epoch 00054: val_acc improved from 0.74409 to 0.74803, saving model to weights.best.hdf5
#
# Epoch 00055: val_acc did not improve from 0.74803
#
# Epoch 00056: val_acc did not improve from 0.74803
#
# Epoch 00057: val_acc did not improve from 0.74803
#
# Epoch 00058: val_acc did not improve from 0.74803
#
# Epoch 00059: val_acc did not improve from 0.74803
#
# Epoch 00060: val_acc did not improve from 0.74803
#
# Epoch 00061: val_acc did not improve from 0.74803
#
# Epoch 00062: val_acc improved from 0.74803 to 0.75197, saving model to weights.best.hdf5
#
# Epoch 00063: val_acc did not improve from 0.75197
#
# Epoch 00064: val_acc did not improve from 0.75197
#
# Epoch 00065: val_acc did not improve from 0.75197
#
# Epoch 00066: val_acc improved from 0.75197 to 0.76378, saving model to weights.best.hdf5
#
# Epoch 00067: val_acc did not improve from 0.76378
#
# Epoch 00068: val_acc did not improve from 0.76378
#
# Epoch 00069: val_acc did not improve from 0.76378
#
# Epoch 00070: val_acc did not improve from 0.76378
#
# Epoch 00071: val_acc did not improve from 0.76378
#
# Epoch 00072: val_acc improved from 0.76378 to 0.76772, saving model to weights.best.hdf5
#
# Epoch 00073: val_acc did not improve from 0.76772
#
# Epoch 00074: val_acc did not improve from 0.76772
#
# Epoch 00075: val_acc did not improve from 0.76772
#
# Epoch 00076: val_acc did not improve from 0.76772
#
# Epoch 00077: val_acc did not improve from 0.76772
#
# Epoch 00078: val_acc did not improve from 0.76772
#
# Epoch 00079: val_acc did not improve from 0.76772
#
# Epoch 00080: val_acc improved from 0.76772 to 0.77559, saving model to weights.best.hdf5
#
# Epoch 00081: val_acc did not improve from 0.77559
#
# Epoch 00082: val_acc did not improve from 0.77559
#
# Epoch 00083: val_acc did not improve from 0.77559
#
# Epoch 00084: val_acc did not improve from 0.77559
#
# Epoch 00085: val_acc did not improve from 0.77559
#
# Epoch 00086: val_acc did not improve from 0.77559
#
# Epoch 00087: val_acc did not improve from 0.77559
#
# Epoch 00088: val_acc did not improve from 0.77559
#
# Epoch 00089: val_acc improved from 0.77559 to 0.77559, saving model to weights.best.hdf5
#
# Epoch 00090: val_acc did not improve from 0.77559
#
# Epoch 00091: val_acc did not improve from 0.77559
#
# Epoch 00092: val_acc did not improve from 0.77559
#
# Epoch 00093: val_acc did not improve from 0.77559
#
# Epoch 00094: val_acc did not improve from 0.77559
#
# Epoch 00095: val_acc did not improve from 0.77559
#
# Epoch 00096: val_acc did not improve from 0.77559
#
# Epoch 00097: val_acc did not improve from 0.77559
#
# Epoch 00098: val_acc did not improve from 0.77559
#
# Epoch 00099: val_acc did not improve from 0.77559
#
# Epoch 00100: val_acc improved from 0.77559 to 0.78740, saving model to weights.best.hdf5
#
# Epoch 00101: val_acc did not improve from 0.78740
#
# Epoch 00102: val_acc improved from 0.78740 to 0.78740, saving model to weights.best.hdf5
#
# Epoch 00103: val_acc did not improve from 0.78740
#
# Epoch 00104: val_acc did not improve from 0.78740
#
# Epoch 00105: val_acc did not improve from 0.78740
#
# Epoch 00106: val_acc did not improve from 0.78740
#
# Epoch 00107: val_acc did not improve from 0.78740
#
# Epoch 00108: val_acc did not improve from 0.78740
#
# Epoch 00109: val_acc did not improve from 0.78740
#
# Epoch 00110: val_acc did not improve from 0.78740
#
# Epoch 00111: val_acc did not improve from 0.78740
#
# Epoch 00112: val_acc did not improve from 0.78740
#
# Epoch 00113: val_acc did not improve from 0.78740
#
# Epoch 00114: val_acc did not improve from 0.78740
#
# Epoch 00115: val_acc did not improve from 0.78740
#
# Epoch 00116: val_acc did not improve from 0.78740
#
# Epoch 00117: val_acc did not improve from 0.78740
#
# Epoch 00118: val_acc did not improve from 0.78740
#
# Epoch 00119: val_acc did not improve from 0.78740
#
# Epoch 00120: val_acc did not improve from 0.78740
#
# Epoch 00121: val_acc did not improve from 0.78740
#
# Epoch 00122: val_acc did not improve from 0.78740
#
# Epoch 00123: val_acc did not improve from 0.78740
#
# Epoch 00124: val_acc did not improve from 0.78740
#
# Epoch 00125: val_acc did not improve from 0.78740
#
# Epoch 00126: val_acc did not improve from 0.78740
#
# Epoch 00127: val_acc improved from 0.78740 to 0.79528, saving model to weights.best.hdf5
#
# Epoch 00128: val_acc did not improve from 0.79528
#
# Epoch 00129: val_acc did not improve from 0.79528
#
# Epoch 00130: val_acc did not improve from 0.79528
#
# Epoch 00131: val_acc did not improve from 0.79528
#
# Epoch 00132: val_acc did not improve from 0.79528
#
# Epoch 00133: val_acc did not improve from 0.79528
#
# Epoch 00134: val_acc did not improve from 0.79528
#
# Epoch 00135: val_acc did not improve from 0.79528
#
# Epoch 00136: val_acc improved from 0.79528 to 0.80315, saving model to weights.best.hdf5
#
# Epoch 00137: val_acc did not improve from 0.80315
#
# Epoch 00138: val_acc did not improve from 0.80315
#
# Epoch 00139: val_acc did not improve from 0.80315
#
# Epoch 00140: val_acc did not improve from 0.80315
#
# Epoch 00141: val_acc did not improve from 0.80315
#
# Epoch 00142: val_acc did not improve from 0.80315
#
# Epoch 00143: val_acc did not improve from 0.80315
#
# Epoch 00144: val_acc did not improve from 0.80315
#
# Epoch 00145: val_acc did not improve from 0.80315
# Epoch 00146: val_acc did not improve from 0.80315
#
# Epoch 00147: val_acc did not improve from 0.80315
#
# Epoch 00148: val_acc did not improve from 0.80315
#
# Epoch 00149: val_acc did not improve from 0.80315
#
# Epoch 00150: val_acc did not improve from 0.80315

# %%
### Loading a Saved Neural Network Model
# load weights file, assume you already know the network structure
from keras.models import Sequential
from keras.layers import Dense
import numpy

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
# load weights
model.load_weights("weights.best.hdf5")
# compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")
#load pima indians dataset
dataset = numpy.loadtxt("../datasets/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:, 0:8]
Y = dataset[:, 8]
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-7b983028a2c2> in <module>()
#      14 model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
#      15 # load weights
# ---> 16 model.load_weights("weights.bast.hdf5")
#      17 # compile model (required to make predictions)
#      18 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#
# ~/anaconda3/envs/dl_env/lib/python3.6/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1169         if h5py is None:
#    1170             raise ImportError('`load_weights` requires h5py.')
# -> 1171         with h5py.File(filepath, mode='r') as f:
#    1172             if 'layer_names' not in f.attrs and 'model_weights' in f:
#    1173                 f = f['model_weights']
#
# ~/anaconda3/envs/dl_env/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~/anaconda3/envs/dl_env/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# --> 142         fid = h5f.open(name, flags, fapl=fapl)
#     143     elif mode == 'r+':
#     144         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'weights.bast.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
